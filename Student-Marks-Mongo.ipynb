# %%
# !mongoimport --db db_student --collection col_student --file students.json

# %%
import pymongo
import json

# Connect to MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["db_student"]
collection = db["col_student"]

for document in collection.find():
    print(document)
# Out:
# {'_id': 0, 'name': 'aimee Zank', 'scores': [{'score': 1.463179736705023, 'type': 'exam'}, {'score': 11.78273309957772, 'type': 'quiz'}, {'score': 35.8740349954354, 'type': 'homework'}]}
# {'_id': 2, 'name': 'Corliss Zuk', 'scores': [{'score': 67.03077096065002, 'type': 'exam'}, {'score': 6.301851677835235, 'type': 'quiz'}, {'score': 66.28344683278382, 'type': 'homework'}]}
# {'_id': 3, 'name': 'Bao Ziglar', 'scores': [{'score': 71.64343899778332, 'type': 'exam'}, {'score': 24.80221293650313, 'type': 'quiz'}, {'score': 42.26147058804812, 'type': 'homework'}]}
# {'_id': 4, 'name': 'Zachary Langlais', 'scores': [{'score': 78.68385091304332, 'type': 'exam'}, {'score': 90.2963101368042, 'type': 'quiz'}, {'score': 34.41620148042529, 'type': 'homework'}]}
# {'_id': 1, 'name': 'Aurelia Menendez', 'scores': [{'score': 60.06045071030959, 'type': 'exam'}, {'score': 52.79790691903873, 'type': 'quiz'}, {'score': 71.76133439165544, 'type': 'homework'}]}
# ...

# %% [markdown]
# ### 1)      Find the student name who scored maximum scores in all (exam, quiz and homework)?

# %%
result_max_marks=collection.aggregate([
{"$project":{"_id":0,"name":1,"max_marks":{"$sum":"$scores.score"}}},
])
print("Create a projection of maximum marks")
for i in result_max_marks:
    print(i)
# Out:
# Create a projection of maximum marks
# {'name': 'aimee Zank', 'max_marks': 49.11994783171814}
# {'name': 'Corliss Zuk', 'max_marks': 139.61606947126907}
# {'name': 'Bao Ziglar', 'max_marks': 138.70712252233457}
# {'name': 'Zachary Langlais', 'max_marks': 203.3963625302728}
# {'name': 'Aurelia Menendez', 'max_marks': 184.61969202100374}
# {'name': 'Jenette Flanders', 'max_marks': 147.2203575476617}
# {'name': 'Salena Olmos', 'max_marks': 229.3959334774732}
# {'name': 'Wilburn Spiess', 'max_marks': 134.0186975547794}
# {'name': 'Daphne Zheng', 'max_marks': 112.71677331754347}
# {'name': 'Denisha Cast', 'max_marks': 199.8843572885121}
# {'name': 'Marcus Blohm', 'max_marks': 248.5091538691126}
# {'name': 'Quincy Danaher', 'max_marks': 220.3184379933348}
# {'name': 'Jessika Dagenais', 'max_marks': 275.94947751518237}
# {'name': 'Alix Sherrill', 'max_marks': 118.48870352377075}
# {'name': 'Dodie Staller', 'max_marks': 120.13675287379564}
# ...

# %%
print("Student name who scored maximum scores in all (exam, quiz and homework)")
result_max_marks=collection.aggregate([
                                        {"$project":{"_id":0,"name":1,"max_marks":{"$sum":"$scores.score"}}},
                                        {"$sort":{"max_marks":-1}},{"$limit":1}
                                      ])
for i in result_max_marks:
    print(i['name'])
# Out:
# Student name who scored maximum scores in all (exam, quiz and homework)
# Jessika Dagenais

# %% [markdown]
# ### 2)      Find students who scored below average in the exam and pass mark is 40%?

# %%
sum=0
count=0
for doc in collection.find({},{"_id":0,"scores":1}):
    sum+=(doc["scores"][0]["score"])
    count+=1

avg=sum/count

print("average =",avg)
print("Students who scored below average in the exam and pass mark is 40%")
print('-'*20)
for doc in collection.find({},{"_id":0}):
    if doc["scores"][0]["score"]>=40 and doc["scores"][0]["score"]<=avg:
        print(doc["name"])
#         print(doc)

print('-'*20)
# Out:
# average = 48.673670759501775
# Students who scored below average in the exam and pass mark is 40%
# --------------------
# Wilburn Spiess
# Denisha Cast
# Tressa Schwing
# Gisela Levin
# Rosana Vales
# Tamika Schildgen
# Gwyneth Garling
# Terica Brugger
# Kayce Kenyon
# Chad Rahe
# Jenise Mcguffie
# Cassi Heal
# Demarcus Audette
# Flora Duell
# Quincy Danaher
# Alix Sherrill
# Laureen Salomone
# Gwyneth Garling
# Aleida Elsass
# Alica Pasley
# Malisa Jeanes
# Harriett Velarde
# Mariela Sherer
# --------------------

# %% [markdown]
# ### 3)      Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.

# %%
print("below 40 marks subjectwise updated as fail")
c=collection.aggregate([{"$unwind":"$scores"},
    {"$match":{"scores.score": {"$lt": 40}}},
    {"$project":{"_id":0,"student_name":"$name","type_of_exam_failed":"$scores.type", "result": "Fail"}}])
for i in c:
    print(i)
# Out:
# below 40 marks subjectwise updated as fail
# {'student_name': 'aimee Zank', 'type_of_exam_failed': 'exam', 'result': 'Fail'}
# {'student_name': 'aimee Zank', 'type_of_exam_failed': 'quiz', 'result': 'Fail'}
# {'student_name': 'aimee Zank', 'type_of_exam_failed': 'homework', 'result': 'Fail'}
# {'student_name': 'Corliss Zuk', 'type_of_exam_failed': 'quiz', 'result': 'Fail'}
# {'student_name': 'Bao Ziglar', 'type_of_exam_failed': 'quiz', 'result': 'Fail'}
# {'student_name': 'Zachary Langlais', 'type_of_exam_failed': 'homework', 'result': 'Fail'}
# {'student_name': 'Jenette Flanders', 'type_of_exam_failed': 'exam', 'result': 'Fail'}
# {'student_name': 'Jenette Flanders', 'type_of_exam_failed': 'quiz', 'result': 'Fail'}
# {'student_name': 'Wilburn Spiess', 'type_of_exam_failed': 'quiz', 'result': 'Fail'}
# {'student_name': 'Daphne Zheng', 'type_of_exam_failed': 'exam', 'result': 'Fail'}
# {'student_name': 'Daphne Zheng', 'type_of_exam_failed': 'quiz', 'result': 'Fail'}
# ...

# %% [markdown]
# ### 4)       Find the total and average of the exam, quiz and homework and store them in a separate collection.

# %%
c=collection.aggregate([
    {"$project":{"_id":0,"name":1,"total":{"$sum":"$scores.score"},"average":{"$avg":"$scores.score"}}}
])
mycol_total_avg=db["total_avg_collections"]
for i in c:
    print(i)
    mycol_total_avg.insert_one(i)
# Out:
# {'name': 'aimee Zank', 'total': 49.11994783171814, 'average': 16.373315943906046}
# {'name': 'Corliss Zuk', 'total': 139.61606947126907, 'average': 46.53868982375636}
# {'name': 'Bao Ziglar', 'total': 138.70712252233457, 'average': 46.23570750744486}
# {'name': 'Zachary Langlais', 'total': 203.3963625302728, 'average': 67.79878751009093}
# {'name': 'Aurelia Menendez', 'total': 184.61969202100374, 'average': 61.53989734033458}
# {'name': 'Jenette Flanders', 'total': 147.2203575476617, 'average': 49.07345251588723}
# {'name': 'Salena Olmos', 'total': 229.3959334774732, 'average': 76.46531115915774}
# {'name': 'Wilburn Spiess', 'total': 134.0186975547794, 'average': 44.67289918492647}
# {'name': 'Daphne Zheng', 'total': 112.71677331754347, 'average': 37.57225777251449}
# {'name': 'Denisha Cast', 'total': 199.8843572885121, 'average': 66.62811909617069}
# {'name': 'Marcus Blohm', 'total': 248.5091538691126, 'average': 82.83638462303753}
# ...

# %%
for doc in mycol_total_avg.find({},{"_id":0}):      #for viewing inserted elements
    print(doc)
# Out:
# {'name': 'aimee Zank', 'total': 49.11994783171814, 'average': 16.373315943906046}
# {'name': 'Corliss Zuk', 'total': 139.61606947126907, 'average': 46.53868982375636}
# {'name': 'Bao Ziglar', 'total': 138.70712252233457, 'average': 46.23570750744486}
# {'name': 'Zachary Langlais', 'total': 203.3963625302728, 'average': 67.79878751009093}
# {'name': 'Aurelia Menendez', 'total': 184.61969202100374, 'average': 61.53989734033458}
# {'name': 'Jenette Flanders', 'total': 147.2203575476617, 'average': 49.07345251588723}
# {'name': 'Salena Olmos', 'total': 229.3959334774732, 'average': 76.46531115915774}
# {'name': 'Wilburn Spiess', 'total': 134.0186975547794, 'average': 44.67289918492647}
# {'name': 'Daphne Zheng', 'total': 112.71677331754347, 'average': 37.57225777251449}
# {'name': 'Denisha Cast', 'total': 199.8843572885121, 'average': 66.62811909617069}
# {'name': 'Marcus Blohm', 'total': 248.5091538691126, 'average': 82.83638462303753}
# ...

# %% [markdown]
# ### 5)      Create a new collection which consists of students who scored below average and above 40% in all the categories.

# %%
c=mycol_total_avg.aggregate([
    {"$group":{"_id":0,"average_of_total":{"$avg":"$total"}}}
])
for i in c:
    print(i)
average_of_total=i["average_of_total"]
print("scored below average and above 40% in all the categories")
mycol_1=db["score_below_avg_above_40_in_all_category"]
for j in mycol_total_avg.find({"total":{"$gte":40,"$lt":average_of_total}},{"_id":0,"name":1}):
    print(j)
    mycol_1.insert_one(j)
# Out:
# {'_id': 0, 'average_of_total': 165.4890901604158}
# scored below average and above 40% in all the categories
# {'name': 'aimee Zank'}
# {'name': 'Corliss Zuk'}
# {'name': 'Bao Ziglar'}
# {'name': 'Jenette Flanders'}
# {'name': 'Wilburn Spiess'}
# {'name': 'Daphne Zheng'}
# {'name': 'Alix Sherrill'}
# {'name': 'Dodie Staller'}
# {'name': 'Tambra Mercure'}
# {'name': 'Gisela Levin'}
# {'name': 'Jesusa Rickenbacker'}
# {'name': 'Rudolph Domingo'}
# {'name': 'Edgar Sarkis'}
# {'name': 'Jonie Raby'}
# {'name': 'Laureen Salomone'}
# {'name': 'Gwyneth Garling'}
# {'name': 'Kaila Deibler'}
# {'name': 'Tandra Meadows'}
# {'name': 'Synthia Labelle'}
# {'name': 'Carli Belvins'}
# {'name': 'Sadie Jernigan'}
# {'name': 'Mariette Batdorf'}
# {'name': 'Houston Valenti'}
# {'name': 'Terica Brugger'}
# {'name': 'Lady Lefevers'}
# {'name': 'Ernestine Macfarland'}
# {'name': 'Kurtis Jiles'}
# {'name': 'Danika Loeffler'}
# {'name': 'Joaquina Arbuckle'}
# {'name': 'Chad Rahe'}
# ...

# %% [markdown]
# ### 6)      Create a new collection which consists of students who scored below the fail mark in all the categories.

# %%
mycol_fail_all=db["fail_all_subj"]
print("students who scored below the fail mark in all the categories")
for i in collection.find({"$and":[{"scores.0.score":{"$lt":40}},
            {"scores.1.score":{"$lt":40}},
            {"scores.2.score":{"$lt":40}}]
             },{"_id":0}):
    mycol_fail_all.insert_one(i)
    print(i)
# Out:
# students who scored below the fail mark in all the categories
# {'name': 'aimee Zank', 'scores': [{'score': 1.463179736705023, 'type': 'exam'}, {'score': 11.78273309957772, 'type': 'quiz'}, {'score': 35.8740349954354, 'type': 'homework'}], '_id': ObjectId('63eb84c6bd236677524ebbdf')}

# %% [markdown]
# ### 7)      Create a new collection which consists of students who scored above pass mark in all the categories.

# %%
mycol_pass_all=db["pass_all_subj"]
print("students who scored above pass mark in all the categories")
for i in collection.find({"$and":[{"scores.0.score":{"$gte":40}},
            {"scores.1.score":{"$gte":40}},
            {"scores.2.score":{"$gte":40}}]
             },{"_id":0}):
    mycol_pass_all.insert_one(i)
    print(i)
# Out:
# students who scored above pass mark in all the categories
# {'name': 'Aurelia Menendez', 'scores': [{'score': 60.06045071030959, 'type': 'exam'}, {'score': 52.79790691903873, 'type': 'quiz'}, {'score': 71.76133439165544, 'type': 'homework'}], '_id': ObjectId('63eb84d9bd236677524ebbe0')}
# {'name': 'Salena Olmos', 'scores': [{'score': 90.37826509157176, 'type': 'exam'}, {'score': 42.48780666956811, 'type': 'quiz'}, {'score': 96.52986171633331, 'type': 'homework'}], '_id': ObjectId('63eb84d9bd236677524ebbe1')}
# {'name': 'Denisha Cast', 'scores': [{'score': 45.61876862259409, 'type': 'exam'}, {'score': 98.35723209418343, 'type': 'quiz'}, {'score': 55.90835657173456, 'type': 'homework'}], '_id': ObjectId('63eb84d9bd236677524ebbe2')}
# {'name': 'Marcus Blohm', 'scores': [{'score': 78.42617835651868, 'type': 'exam'}, {'score': 82.58372817930675, 'type': 'quiz'}, {'score': 87.49924733328717, 'type': 'homework'}], '_id': ObjectId('63eb84d9bd236677524ebbe3')}
# ...
